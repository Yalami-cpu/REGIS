# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
# I have to make sure that the chrun data 2 has similar features with the new churn data of the professor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Churn Data/prepped_churn_data_2.csv', index_col= 'customerID')
df
# Out:
#             tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG       1             0         0              0           29.85
# 5575-GNVDE      34             1         1              1           56.95
# 3668-QPYBK       2             1         0              1           53.85
# 7795-CFOCW      45             0         1              2           42.30
# 9237-HQITU       2             1         0              0           70.70
# ...            ...           ...       ...            ...             ...
# 6840-RESVB      24             1         1              1           84.80
# 2234-XADUH      72             1         1              3          103.20
# 4801-JZAZL      11             0         0              0           29.60
# 8361-LTMKD       4             1         0              1           74.40
# 3186-AJIEK      66             1         2              2          105.65
#
#             TotalCharges  Churn  tenure_MonthlyCharges_ratio  \
# customerID
# 7590-VHVEG         29.85      0                     0.033501
# 5575-GNVDE       1889.50      0                     0.597015
# 3668-QPYBK        108.15      1                     0.037140
# 7795-CFOCW       1840.75      0                     1.063830
# 9237-HQITU        151.65      1                     0.028289
# ...                  ...    ...                          ...
# 6840-RESVB       1990.50      0                     0.283019
# 2234-XADUH       7362.90      0                     0.697674
# 4801-JZAZL        346.45      0                     0.371622
# 8361-LTMKD        306.60      1                     0.053763
# 3186-AJIEK       6844.50      0                     0.624704
#
#             charges_per_month
# customerID
# 7590-VHVEG          29.850000
# 5575-GNVDE          55.573529
# 3668-QPYBK          54.075000
# 7795-CFOCW          40.905556
# 9237-HQITU          75.825000
# ...                       ...
# 6840-RESVB          82.937500
# 2234-XADUH         102.262500
# 4801-JZAZL          31.495455
# 8361-LTMKD          76.650000
# 3186-AJIEK         103.704545
#
# [7032 rows x 9 columns]

# %% [markdown]
# # AutoML with pycaret

# %%
import subprocess
import sys
def install_pycaret():
    try:
        import pycaret
    except ImportError:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'pycaret'])

install_pycaret()

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %%
automl = setup(df, target = 'Churn')
# Out:
# <style type="text/css">
# #T_4973c_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4973c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4973c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4973c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4973c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4973c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4973c_row0_col1" class="data row0 col1" >2299</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4973c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4973c_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4973c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4973c_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4973c_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_4973c_row3_col1" class="data row3 col1" >(7032, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4973c_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_4973c_row4_col1" class="data row4 col1" >(7032, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4973c_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_4973c_row5_col1" class="data row5 col1" >(4922, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4973c_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_4973c_row6_col1" class="data row6 col1" >(2110, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4973c_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_4973c_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4973c_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_4973c_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4973c_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_4973c_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4973c_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_4973c_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4973c_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_4973c_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4973c_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_4973c_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4973c_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_4973c_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4973c_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_4973c_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4973c_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_4973c_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4973c_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_4973c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4973c_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_4973c_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4973c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4973c_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_4973c_row18_col1" class="data row18 col1" >657f</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_6adc4 th {
#   text-align: left;
# }
# #T_6adc4_row0_col0, #T_6adc4_row0_col2, #T_6adc4_row0_col3, #T_6adc4_row0_col4, #T_6adc4_row0_col5, #T_6adc4_row0_col7, #T_6adc4_row1_col0, #T_6adc4_row1_col1, #T_6adc4_row1_col2, #T_6adc4_row1_col3, #T_6adc4_row1_col5, #T_6adc4_row1_col6, #T_6adc4_row1_col7, #T_6adc4_row2_col0, #T_6adc4_row2_col1, #T_6adc4_row2_col2, #T_6adc4_row2_col3, #T_6adc4_row2_col4, #T_6adc4_row2_col5, #T_6adc4_row2_col6, #T_6adc4_row2_col7, #T_6adc4_row3_col0, #T_6adc4_row3_col1, #T_6adc4_row3_col2, #T_6adc4_row3_col3, #T_6adc4_row3_col4, #T_6adc4_row3_col5, #T_6adc4_row3_col6, #T_6adc4_row3_col7, #T_6adc4_row4_col0, #T_6adc4_row4_col1, #T_6adc4_row4_col3, #T_6adc4_row4_col4, #T_6adc4_row4_col5, #T_6adc4_row4_col6, #T_6adc4_row4_col7, #T_6adc4_row5_col0, #T_6adc4_row5_col1, #T_6adc4_row5_col2, #T_6adc4_row5_col3, #T_6adc4_row5_col4, #T_6adc4_row5_col5, #T_6adc4_row5_col6, #T_6adc4_row5_col7, #T_6adc4_row6_col0, #T_6adc4_row6_col1, #T_6adc4_row6_col2, #T_6adc4_row6_col3, #T_6adc4_row6_col4, #T_6adc4_row6_col5, #T_6adc4_row6_col6, #T_6adc4_row6_col7, #T_6adc4_row7_col0, #T_6adc4_row7_col1, #T_6adc4_row7_col2, #T_6adc4_row7_col3, #T_6adc4_row7_col4, #T_6adc4_row7_col5, #T_6adc4_row7_col6, #T_6adc4_row7_col7, #T_6adc4_row8_col0, #T_6adc4_row8_col1, #T_6adc4_row8_col2, #T_6adc4_row8_col3, #T_6adc4_row8_col4, #T_6adc4_row8_col5, #T_6adc4_row8_col6, #T_6adc4_row8_col7, #T_6adc4_row9_col0, #T_6adc4_row9_col1, #T_6adc4_row9_col2, #T_6adc4_row9_col3, #T_6adc4_row9_col4, #T_6adc4_row9_col5, #T_6adc4_row9_col6, #T_6adc4_row9_col7, #T_6adc4_row10_col0, #T_6adc4_row10_col1, #T_6adc4_row10_col2, #T_6adc4_row10_col3, #T_6adc4_row10_col4, #T_6adc4_row10_col5, #T_6adc4_row10_col6, #T_6adc4_row10_col7, #T_6adc4_row11_col0, #T_6adc4_row11_col1, #T_6adc4_row11_col2, #T_6adc4_row11_col3, #T_6adc4_row11_col4, #T_6adc4_row11_col5, #T_6adc4_row11_col6, #T_6adc4_row11_col7, #T_6adc4_row12_col0, #T_6adc4_row12_col1, #T_6adc4_row12_col2, #T_6adc4_row12_col4, #T_6adc4_row12_col6, #T_6adc4_row13_col0, #T_6adc4_row13_col1, #T_6adc4_row13_col2, #T_6adc4_row13_col3, #T_6adc4_row13_col4, #T_6adc4_row13_col5, #T_6adc4_row13_col6, #T_6adc4_row13_col7, #T_6adc4_row14_col0, #T_6adc4_row14_col1, #T_6adc4_row14_col2, #T_6adc4_row14_col3, #T_6adc4_row14_col4, #T_6adc4_row14_col5, #T_6adc4_row14_col6, #T_6adc4_row14_col7 {
#   text-align: left;
# }
# #T_6adc4_row0_col1, #T_6adc4_row0_col6, #T_6adc4_row1_col4, #T_6adc4_row4_col2, #T_6adc4_row12_col3, #T_6adc4_row12_col5, #T_6adc4_row12_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6adc4_row0_col8, #T_6adc4_row1_col8, #T_6adc4_row2_col8, #T_6adc4_row3_col8, #T_6adc4_row4_col8, #T_6adc4_row5_col8, #T_6adc4_row6_col8, #T_6adc4_row7_col8, #T_6adc4_row8_col8, #T_6adc4_row9_col8, #T_6adc4_row11_col8, #T_6adc4_row12_col8, #T_6adc4_row13_col8, #T_6adc4_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6adc4_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6adc4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6adc4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6adc4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6adc4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6adc4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6adc4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6adc4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6adc4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6adc4_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6adc4_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6adc4_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_6adc4_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_6adc4_row0_col1" class="data row0 col1" >0.7911</td>
#       <td id="T_6adc4_row0_col2" class="data row0 col2" >0.8331</td>
#       <td id="T_6adc4_row0_col3" class="data row0 col3" >0.5122</td>
#       <td id="T_6adc4_row0_col4" class="data row0 col4" >0.6315</td>
#       <td id="T_6adc4_row0_col5" class="data row0 col5" >0.5653</td>
#       <td id="T_6adc4_row0_col6" class="data row0 col6" >0.4300</td>
#       <td id="T_6adc4_row0_col7" class="data row0 col7" >0.4342</td>
#       <td id="T_6adc4_row0_col8" class="data row0 col8" >0.3630</td>
#     </tr>
#     <tr>
#       <th id="T_6adc4_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_6adc4_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_6adc4_row1_col1" class="data row1 col1" >0.7903</td>
#       <td id="T_6adc4_row1_col2" class="data row1 col2" >0.8230</td>
#       <td id="T_6adc4_row1_col3" class="data row1 col3" >0.4472</td>
#       <td id="T_6adc4_row1_col4" class="data row1 col4" >0.6540</td>
#       <td id="T_6adc4_row1_col5" class="data row1 col5" >0.5311</td>
#       <td id="T_6adc4_row1_col6" class="data row1 col6" >0.4022</td>
#       <td id="T_6adc4_row1_col7" class="data row1 col7" >0.4143</td>
#       <td id="T_6adc4_row1_col8" class="data row1 col8" >0.0510</td>
#     </tr>
#     <tr>
#       <th id="T_6adc4_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_6adc4_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_6adc4_row2_col1" class="data row2 col1" >0.7901</td>
#       <td id="T_6adc4_row2_col2" class="data row2 col2" >0.8230</td>
#       <td id="T_6adc4_row2_col3" class="data row2 col3" >0.5069</td>
#       <td id="T_6adc4_row2_col4" class="data row2 col4" >0.6307</td>
#       <td id="T_6adc4_row2_col5" class="data row2 col5" >0.5617</td>
#       <td id="T_6adc4_row2_col6" class="data row2 col6" >0.4260</td>
#       <td id="T_6adc4_row2_col7" class="data row2 col7" >0.4306</td>
#       <td id="T_6adc4_row2_col8" class="data row2 col8" >0.0290</td>
#     </tr>
#     <tr>
#       <th id="T_6adc4_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_6adc4_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_6adc4_row3_col1" class="data row3 col1" >0.7877</td>
#       <td id="T_6adc4_row3_col2" class="data row3 col2" >0.8283</td>
#       <td id="T_6adc4_row3_col3" class="data row3 col3" >0.4908</td>
#       <td id="T_6adc4_row3_col4" class="data row3 col4" >0.6293</td>
#       <td id="T_6adc4_row3_col5" class="data row3 col5" >0.5507</td>
#       <td id="T_6adc4_row3_col6" class="data row3 col6" >0.4147</td>
#       <td id="T_6adc4_row3_col7" class="data row3 col7" >0.4206</td>
#       <td id="T_6adc4_row3_col8" class="data row3 col8" >0.2390</td>
#     </tr>
#     <tr>
#       <th id="T_6adc4_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_6adc4_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6adc4_row4_col1" class="data row4 col1" >0.7861</td>
#       <td id="T_6adc4_row4_col2" class="data row4 col2" >0.8340</td>
#       <td id="T_6adc4_row4_col3" class="data row4 col3" >0.4709</td>
#       <td id="T_6adc4_row4_col4" class="data row4 col4" >0.6318</td>
#       <td id="T_6adc4_row4_col5" class="data row4 col5" >0.5389</td>
#       <td id="T_6adc4_row4_col6" class="data row4 col6" >0.4036</td>
#       <td id="T_6adc4_row4_col7" class="data row4 col7" >0.4113</td>
#       <td id="T_6adc4_row4_col8" class="data row4 col8" >0.9060</td>
#     </tr>
#     <tr>
#       <th id="T_6adc4_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_6adc4_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6adc4_row5_col1" class="data row5 col1" >0.7783</td>
#       <td id="T_6adc4_row5_col2" class="data row5 col2" >0.8200</td>
#       <td id="T_6adc4_row5_col3" class="data row5 col3" >0.4939</td>
#       <td id="T_6adc4_row5_col4" class="data row5 col4" >0.6006</td>
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
best_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=2299, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# It looks like our best model is LogisticRegression, closely followed by ridge and lda

# %%
df.iloc[-2:-1].shape
# Out:
# (1, 9)

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_8177a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8177a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_8177a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_8177a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_8177a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_8177a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_8177a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_8177a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_8177a_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8177a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8177a_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_8177a_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_8177a_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_8177a_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_8177a_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_8177a_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_8177a_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_8177a_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#             tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4             1         0              1       74.400002
#
#             TotalCharges  tenure_MonthlyCharges_ratio  charges_per_month  \
# customerID
# 8361-LTMKD    306.600006                     0.053763          76.650002
#
#             Churn  prediction_label  prediction_score
# customerID
# 8361-LTMKD      1                 1            0.5671

# %% [markdown]
# # Saving and loading our model

# %%
save_model(best_model, 'LDA')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['tenure', 'PhoneService',
#                                               'Contract', 'PaymentMethod',
#                                               'MonthlyCharges', 'TotalCharges',
#                                               'tenure_MonthlyCharges_ratio',
#                                               'charges_per_month'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_val...
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                      fit_intercept=True, intercept_scaling=1,
#                                      l1_ratio=None, max_iter=1000,
#                                      multi_class='auto', n_jobs=None,
#                                      penalty='l2', random_state=2299,
#                                      solver='lbfgs', tol=0.0001, verbose=0,
#                                      warm_start=False))],
#           verbose=False),
#  'LDA.pkl')

# %%
import pickle

with open('LDA_model.pk', 'wb') as f:
    pickle.dump(best_model, f)

# %%
with open('LDA_model.pk', 'rb') as f:
    loaded_model = pickle.load(f)

# %%
new_data = df.iloc[-2:-1].copy()
new_data.drop('Churn', axis=1, inplace=True)
loaded_model.predict(new_data)
# Out:
# array([1], dtype=int8)

# %%
loaded_lda = load_model('LDA')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predict_model(loaded_lda, new_data)
# Out:
#             tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4             1         0              1       74.400002
#
#             TotalCharges  tenure_MonthlyCharges_ratio  charges_per_month  \
# customerID
# 8361-LTMKD    306.600006                     0.053763          76.650002
#
#             prediction_label  prediction_score
# customerID
# 8361-LTMKD                 1            0.5671

# %% [markdown]
# # Making a Python module to make predictions

# %%
from IPython.display import Code

Code('/content/drive/MyDrive/Colab Notebooks/Week 5/predict_churn.py')
# Out:
# # -*- coding: utf-8 -*-
# """Week_5_assignment_starter.ipynb
#
# Automatically generated by Colab.
#
# Original file is located at
#     https://colab.research.google.com/drive/1WxasIgYRyva7CLqIChxKPjxKJhPZvyvt
#
# # DS Automation Assignment
#
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.
# """
#
# # I have to make sure that the chrun data 2 has similar features with the new churn data of the professor
#
# from google.colab import drive
# drive.mount('/content/drive')
#
# import pandas as pd
#
# df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Churn Data/prepped_churn_data_2.csv', index_col= 'customerID')
# df
#
# """# AutoML with pycaret"""
#
# import subprocess
# import sys
# def install_pycaret():
#     try:
#         import pycaret
#     except ImportError:
#         subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'pycaret'])
#
# install_pycaret()
#
# from pycaret.classification import setup, compare_models, predict_model, save_model, load_model
#
# automl = setup(df, target = 'Churn')
#
# best_model = compare_models()
#
# best_model
#
# df.iloc[-2:-1].shape
#
# predict_model(best_model, df.iloc[-2:-1])
#
# """# Saving and loading our model"""
#
# save_model(best_model, 'LDA')
#
# import pickle
#
# with open('LDA_model.pk', 'wb') as f:
#     pickle.dump(best_model, f)
#
# with open('LDA_model.pk', 'rb') as f:
#     loaded_model = pickle.load(f)
#
# new_data = df.iloc[-2:-1].copy()
# new_data.drop('Churn', axis=1, inplace=True)
# loaded_model.predict(new_data)
#
# loaded_lda = load_model('LDA')
#
# predict_model(loaded_lda, new_data)
#
# """# Making a Python module to make predictions"""
#
# from IPython.display import Code
#
# Code('/content/drive/MyDrive/Colab Notebooks/Week 5/predict_churn.py')
#
# # Commented out IPython magic to ensure Python compatibility.
# # %run predict_churn.py
#
# """# Summary
#
# Write a short summary of the process and results here.
# """

# %%
# %run predict_churn.py
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <style type="text/css">
# #T_03865_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_03865" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_03865_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_03865_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03865_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03865_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_03865_row0_col1" class="data row0 col1" >3784</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03865_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_03865_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03865_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_03865_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03865_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_03865_row3_col1" class="data row3 col1" >(7032, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03865_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_03865_row4_col1" class="data row4 col1" >(7032, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_03865_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_03865_row5_col1" class="data row5 col1" >(4922, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_03865_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_03865_row6_col1" class="data row6 col1" >(2110, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_03865_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_03865_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_03865_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_03865_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_03865_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_03865_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_03865_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_03865_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_03865_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_03865_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_03865_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_03865_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_03865_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_03865_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_03865_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_03865_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_03865_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_03865_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_03865_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_03865_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_03865_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_03865_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_03865_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_03865_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_03865_row18_col1" class="data row18 col1" >1774</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_228f6 th {
#   text-align: left;
# }
# #T_228f6_row0_col0, #T_228f6_row0_col2, #T_228f6_row0_col3, #T_228f6_row0_col4, #T_228f6_row0_col5, #T_228f6_row0_col7, #T_228f6_row1_col0, #T_228f6_row1_col1, #T_228f6_row1_col2, #T_228f6_row1_col3, #T_228f6_row1_col4, #T_228f6_row1_col5, #T_228f6_row1_col6, #T_228f6_row1_col7, #T_228f6_row2_col0, #T_228f6_row2_col1, #T_228f6_row2_col3, #T_228f6_row2_col4, #T_228f6_row2_col5, #T_228f6_row2_col6, #T_228f6_row2_col7, #T_228f6_row3_col0, #T_228f6_row3_col1, #T_228f6_row3_col2, #T_228f6_row3_col3, #T_228f6_row3_col5, #T_228f6_row3_col6, #T_228f6_row3_col7, #T_228f6_row4_col0, #T_228f6_row4_col1, #T_228f6_row4_col2, #T_228f6_row4_col3, #T_228f6_row4_col4, #T_228f6_row4_col5, #T_228f6_row4_col6, #T_228f6_row4_col7, #T_228f6_row5_col0, #T_228f6_row5_col1, #T_228f6_row5_col2, #T_228f6_row5_col3, #T_228f6_row5_col4, #T_228f6_row5_col5, #T_228f6_row5_col6, #T_228f6_row5_col7, #T_228f6_row6_col0, #T_228f6_row6_col1, #T_228f6_row6_col2, #T_228f6_row6_col3, #T_228f6_row6_col4, #T_228f6_row6_col5, #T_228f6_row6_col6, #T_228f6_row6_col7, #T_228f6_row7_col0, #T_228f6_row7_col1, #T_228f6_row7_col2, #T_228f6_row7_col3, #T_228f6_row7_col4, #T_228f6_row7_col5, #T_228f6_row7_col6, #T_228f6_row7_col7, #T_228f6_row8_col0, #T_228f6_row8_col1, #T_228f6_row8_col2, #T_228f6_row8_col3, #T_228f6_row8_col4, #T_228f6_row8_col5, #T_228f6_row8_col6, #T_228f6_row8_col7, #T_228f6_row9_col0, #T_228f6_row9_col1, #T_228f6_row9_col2, #T_228f6_row9_col3, #T_228f6_row9_col4, #T_228f6_row9_col5, #T_228f6_row9_col6, #T_228f6_row9_col7, #T_228f6_row10_col0, #T_228f6_row10_col1, #T_228f6_row10_col2, #T_228f6_row10_col3, #T_228f6_row10_col4, #T_228f6_row10_col5, #T_228f6_row10_col6, #T_228f6_row10_col7, #T_228f6_row11_col0, #T_228f6_row11_col1, #T_228f6_row11_col2, #T_228f6_row11_col3, #T_228f6_row11_col4, #T_228f6_row11_col5, #T_228f6_row11_col6, #T_228f6_row11_col7, #T_228f6_row12_col0, #T_228f6_row12_col1, #T_228f6_row12_col2, #T_228f6_row12_col3, #T_228f6_row12_col4, #T_228f6_row12_col5, #T_228f6_row12_col6, #T_228f6_row12_col7, #T_228f6_row13_col0, #T_228f6_row13_col1, #T_228f6_row13_col2, #T_228f6_row13_col4, #T_228f6_row13_col6, #T_228f6_row14_col0, #T_228f6_row14_col1, #T_228f6_row14_col2, #T_228f6_row14_col3, #T_228f6_row14_col4, #T_228f6_row14_col5, #T_228f6_row14_col6, #T_228f6_row14_col7 {
#   text-align: left;
# }
# #T_228f6_row0_col1, #T_228f6_row0_col6, #T_228f6_row2_col2, #T_228f6_row3_col4, #T_228f6_row13_col3, #T_228f6_row13_col5, #T_228f6_row13_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_228f6_row0_col8, #T_228f6_row1_col8, #T_228f6_row2_col8, #T_228f6_row3_col8, #T_228f6_row4_col8, #T_228f6_row5_col8, #T_228f6_row6_col8, #T_228f6_row7_col8, #T_228f6_row8_col8, #T_228f6_row9_col8, #T_228f6_row10_col8, #T_228f6_row12_col8, #T_228f6_row13_col8, #T_228f6_row14_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_228f6_row11_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_228f6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_228f6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_228f6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_228f6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_228f6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_228f6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_228f6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_228f6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_228f6_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_228f6_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_228f6_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_228f6_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_228f6_row0_col1" class="data row0 col1" >0.7899</td>
#       <td id="T_228f6_row0_col2" class="data row0 col2" >0.8330</td>
#       <td id="T_228f6_row0_col3" class="data row0 col3" >0.5107</td>
#       <td id="T_228f6_row0_col4" class="data row0 col4" >0.6295</td>
#       <td id="T_228f6_row0_col5" class="data row0 col5" >0.5637</td>
#       <td id="T_228f6_row0_col6" class="data row0 col6" >0.4274</td>
#       <td id="T_228f6_row0_col7" class="data row0 col7" >0.4315</td>
#       <td id="T_228f6_row0_col8" class="data row0 col8" >0.2860</td>
#     </tr>
#     <tr>
#       <th id="T_228f6_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_228f6_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_228f6_row1_col1" class="data row1 col1" >0.7897</td>
#       <td id="T_228f6_row1_col2" class="data row1 col2" >0.8318</td>
#       <td id="T_228f6_row1_col3" class="data row1 col3" >0.4793</td>
#       <td id="T_228f6_row1_col4" class="data row1 col4" >0.6430</td>
#       <td id="T_228f6_row1_col5" class="data row1 col5" >0.5481</td>
#       <td id="T_228f6_row1_col6" class="data row1 col6" >0.4149</td>
#       <td id="T_228f6_row1_col7" class="data row1 col7" >0.4232</td>
#       <td id="T_228f6_row1_col8" class="data row1 col8" >0.2570</td>
#     </tr>
#     <tr>
#       <th id="T_228f6_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_228f6_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_228f6_row2_col1" class="data row2 col1" >0.7891</td>
#       <td id="T_228f6_row2_col2" class="data row2 col2" >0.8359</td>
#       <td id="T_228f6_row2_col3" class="data row2 col3" >0.4847</td>
#       <td id="T_228f6_row2_col4" class="data row2 col4" >0.6356</td>
#       <td id="T_228f6_row2_col5" class="data row2 col5" >0.5498</td>
#       <td id="T_228f6_row2_col6" class="data row2 col6" >0.4154</td>
#       <td id="T_228f6_row2_col7" class="data row2 col7" >0.4220</td>
#       <td id="T_228f6_row2_col8" class="data row2 col8" >0.8740</td>
#     </tr>
#     <tr>
#       <th id="T_228f6_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_228f6_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_228f6_row3_col1" class="data row3 col1" >0.7881</td>
#       <td id="T_228f6_row3_col2" class="data row3 col2" >0.8230</td>
#       <td id="T_228f6_row3_col3" class="data row3 col3" >0.4388</td>
#       <td id="T_228f6_row3_col4" class="data row3 col4" >0.6504</td>
#       <td id="T_228f6_row3_col5" class="data row3 col5" >0.5238</td>
#       <td id="T_228f6_row3_col6" class="data row3 col6" >0.3941</td>
#       <td id="T_228f6_row3_col7" class="data row3 col7" >0.4069</td>
#       <td id="T_228f6_row3_col8" class="data row3 col8" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_228f6_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_228f6_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_228f6_row4_col1" class="data row4 col1" >0.7879</td>
#       <td id="T_228f6_row4_col2" class="data row4 col2" >0.8231</td>
#       <td id="T_228f6_row4_col3" class="data row4 col3" >0.4962</td>
#       <td id="T_228f6_row4_col4" class="data row4 col4" >0.6279</td>
#       <td id="T_228f6_row4_col5" class="data row4 col5" >0.5540</td>
#       <td id="T_228f6_row4_col6" class="data row4 col6" >0.4175</td>
#       <td id="T_228f6_row4_col7" class="data row4 col7" >0.4226</td>
#       <td id="T_228f6_row4_col8" class="data row4 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_228f6_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_228f6_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_228f6_row5_col1" class="data row5 col1" >0.7816</td>
#       <td id="T_228f6_row5_col2" class="data row5 col2" >0.8254</td>
#       <td id="T_228f6_row5_col3" class="data row5 col3" >0.4985</td>
#       <td id="T_228f6_row5_col4" class="data row5 col4" >0.6097</td>
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# <style type="text/css">
# </style>
# <table id="T_3ba97" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ba97_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3ba97_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3ba97_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3ba97_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3ba97_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3ba97_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3ba97_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3ba97_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ba97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ba97_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_3ba97_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_3ba97_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_3ba97_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_3ba97_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_3ba97_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_3ba97_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_3ba97_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# In the following code I will be adding features in new_data_data.csv to match the prepped_churn_data from week 2 and setting their values to 0 so that we are able to compare the results.

# %%
import pandas as pd
from pycaret.classification import load_model, predict_model

def predict_churn(data_filepath):
    model = load_model('LDA')
    new_data = pd.read_csv(data_filepath)
    new_data['tenure_MonthlyCharges_ratio'] = 0
    new_data['charges_per_month'] = 0
    predictions = predict_model(model, data=new_data)
    predictions.rename(columns={'prediction_label': 'churn_prediction'}, inplace=True)
    print(predictions['churn_prediction'])

if __name__ == "__main__":
       data_filepath = 'new_churn_data.csv'
       predict_churn(data_filepath)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: churn_prediction, dtype: int64

# %% [markdown]
# The true values are (1, 0, 0, 1, 0) so our model is working but it can still be improved. We have one false negative and two false positives.

# %% [markdown]
# # Summary

# %% [markdown]
# For this assignment, I used Pycaret to automatically find the best model for predicting customer churn.
#
# I then saved this model and created a Python script predict_churn.py that can load the model and make predictions on new customer data.
#
# I tested the script with the provided new_churn_data.csv file and compared the predictions to the actual churn values. This showed how effective the model and the automated prediction process are.
